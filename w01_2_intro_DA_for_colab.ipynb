# %% [markdown]
# <a href="https://colab.research.google.com/github/jojeongin313/2024-intro-DA-code/blob/main/w01_2_intro_DA_for_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 데이터 분석 입문
# ## 01주 코딩

# %% [markdown]
# ### markdown은 난이도가 낮으므로 스스로 배워보기
# - markdownguide.org

# %% [markdown]
# ### 코랩을 위한 주피터 노트북 기초
# - 한글 처리
# - 데이터 시각화 기초

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# !pip install koreanize-matplotlib
# Out:
# Requirement already satisfied: koreanize-matplotlib in /usr/local/lib/python3.10/dist-packages (0.1.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from koreanize-matplotlib) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->koreanize-matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->koreanize-matplotlib) (1.16.0)

# %%
import koreanize_matplotlib

# %%
import matplotlib.pyplot as plt

plt.title(' 데이터 시각화의 한글 준비와 기본 직선 그래프')
plt.plot([10,5,25,30])
plt.show()

# %%
import matplotlib.pyplot as plt

plt.title(' 데이터 시각화의 한글 준비와 기본 직선 그래프')
plt.plot([0,1,2,3],[10,5,25,30])
plt.show()

# %%
import pandas as pd

pop = pd.read_csv("202311popmonth.csv", encoding='cp949', index_col=0, thousands=',')
pop
# Out:
#                        2024년08월_총인구수  2024년08월_세대수  2024년08월_세대당 인구  \
# 행정구역
# 전국  (1000000000)            51256511      24087679             2.13
# 서울특별시  (1100000000)          9355801       4487525             2.08
# 부산광역시  (2600000000)          3275593       1570760             2.09
# 대구광역시  (2700000000)          2366033       1101929             2.15
# 인천광역시  (2800000000)          3014770       1368072             2.20
# 광주광역시  (2900000000)          1412063        658010             2.15
# 대전광역시  (3000000000)          1439926        686895             2.10
# 울산광역시  (3100000000)          1099231        494386             2.22
# 세종특별자치시  (3600000000)         389370        162837             2.39
# 경기도  (4100000000)           13675873       6039455             2.26
# 강원특별자치도  (5100000000)        1521066        764793             1.99
# 충청북도  (4300000000)           1590716        785621             2.02
# 충청남도  (4400000000)           2135281       1048985             2.04
# 전북특별자치도  (5200000000)        1743183        864007             2.02
# 전라남도  (4600000000)           1792390        912733             1.96
# 경상북도  (4700000000)           2540046       1291675             1.97
# 경상남도  (4800000000)           3233629       1535333             2.11
# 제주특별자치도  (5000000000)         671540        314663             2.13
#
#                        2024년08월_남자 인구수  2024년08월_여자 인구수  2024년08월_남여 비율
# 행정구역
# 전국  (1000000000)              25522808         25733703            0.99
# 서울특별시  (1100000000)            4518536          4837265            0.93
# 부산광역시  (2600000000)            1594978          1680615            0.95
# 대구광역시  (2700000000)            1161164          1204869            0.96
# 인천광역시  (2800000000)            1506680          1508090            1.00
# 광주광역시  (2900000000)             697079           714984            0.97
# 대전광역시  (3000000000)             717878           722048            0.99
# 울산광역시  (3100000000)             565290           533941            1.06
# 세종특별자치시  (3600000000)           193826           195544            0.99
# 경기도  (4100000000)              6875411          6800462            1.01
# 강원특별자치도  (5100000000)           764911           756155            1.01
# 충청북도  (4300000000)              809546           781170            1.04
# 충청남도  (4400000000)             1095246          1040035            1.05
# 전북특별자치도  (5200000000)           867993           875190            0.99
# 전라남도  (4600000000)              904171           888219            1.02
# 경상북도  (4700000000)             1284828          1255218            1.02
# 경상남도  (4800000000)             1629223          1604406            1.02
# 제주특별자치도  (5000000000)           336048           335492            1.00

# %%
pop.colums=['총인구수','세대수','세대당인구', '남자인구수','여자인구수','남여비율']
pop.head()
# Out:
# <ipython-input-27-7e47c937a968>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   pop.colums=['총인구수','세대수','세대당인구', '남자인구수','여자인구수','남여비율']
#                      2024년08월_총인구수  2024년08월_세대수  2024년08월_세대당 인구  \
# 행정구역
# 전국  (1000000000)          51256511      24087679             2.13
# 서울특별시  (1100000000)        9355801       4487525             2.08
# 부산광역시  (2600000000)        3275593       1570760             2.09
# 대구광역시  (2700000000)        2366033       1101929             2.15
# 인천광역시  (2800000000)        3014770       1368072             2.20
#
#                      2024년08월_남자 인구수  2024년08월_여자 인구수  2024년08월_남여 비율
# 행정구역
# 전국  (1000000000)            25522808         25733703            0.99
# 서울특별시  (1100000000)          4518536          4837265            0.93
# 부산광역시  (2600000000)          1594978          1680615            0.95
# 대구광역시  (2700000000)          1161164          1204869            0.96
# 인천광역시  (2800000000)          1506680          1508090            1.00

# %%
pop.index=[pop.index[i].split()[0] for i in range(len(pop))]
pop
# Out:
#          2024년08월_총인구수  2024년08월_세대수  2024년08월_세대당 인구  2024년08월_남자 인구수  \
# 전국            51256511      24087679             2.13         25522808
# 서울특별시          9355801       4487525             2.08          4518536
# 부산광역시          3275593       1570760             2.09          1594978
# 대구광역시          2366033       1101929             2.15          1161164
# 인천광역시          3014770       1368072             2.20          1506680
# 광주광역시          1412063        658010             2.15           697079
# 대전광역시          1439926        686895             2.10           717878
# 울산광역시          1099231        494386             2.22           565290
# 세종특별자치시         389370        162837             2.39           193826
# 경기도           13675873       6039455             2.26          6875411
# 강원특별자치도        1521066        764793             1.99           764911
# 충청북도           1590716        785621             2.02           809546
# 충청남도           2135281       1048985             2.04          1095246
# 전북특별자치도        1743183        864007             2.02           867993
# 전라남도           1792390        912733             1.96           904171
# 경상북도           2540046       1291675             1.97          1284828
# 경상남도           3233629       1535333             2.11          1629223
# 제주특별자치도         671540        314663             2.13           336048
#
#          2024년08월_여자 인구수  2024년08월_남여 비율
# 전국              25733703            0.99
# 서울특별시            4837265            0.93
# 부산광역시            1680615            0.95
# 대구광역시            1204869            0.96
# 인천광역시            1508090            1.00
# 광주광역시             714984            0.97
# 대전광역시             722048            0.99
# 울산광역시             533941            1.06
# 세종특별자치시           195544            0.99
# 경기도              6800462            1.01
# 강원특별자치도           756155            1.01
# 충청북도              781170            1.04
# 충청남도             1040035            1.05
# 전북특별자치도           875190            0.99
# 전라남도              888219            1.02
# 경상북도             1255218            1.02
# 경상남도             1604406            1.02
# 제주특별자치도           335492            1.00

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(pop['총인구수'])
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '총인구수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-494cfd471080> in <cell line: 4>()
#       2 import seaborn as sns
#       3
# ----> 4 sns.scatterplot(pop['총인구수'])
#       5 plt.xticks(rotation=90)
#       6 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3891             if self.columns.nlevels > 1:
#    3892                 return self._getitem_multilevel(key)
# -> 3893             indexer = self.columns.get_loc(key)
#    3894             if is_integer(indexer):
#    3895                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3796             ):
#    3797                 raise InvalidIndexError(key)
# -> 3798             raise KeyError(key) from err
#    3799         except TypeError:
#    3800             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: '총인구수'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

pop1 = pop.sort_values('총인구수')
sns.barplot(x=pop1.index, y='총인구수', data=pop1)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-ab248331e8f8> in <cell line: 4>()
#       2 import seaborn as sns
#       3
# ----> 4 pop1 = pop.sort_values('총인구수')
#       5 sns.barplot(x=pop1.index, y='총인구수', data=pop1)
#       6 plt.xticks(rotation=90)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6942             # len(by) == 1
#    6943
# -> 6944             k = self._get_label_or_level_values(by[0], axis=axis)
#    6945
#    6946             # need to rewrap column in Series to apply key function
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1842             values = self.axes[axis].get_level_values(key)._values
#    1843         else:
# -> 1844             raise KeyError(key)
#    1845
#    1846         # Check for duplicates
#
# KeyError: '총인구수'
